# %%
# !pip install tensorflow_hub

# %%
import tensorflow_hub as hub
from tensorflow.keras.utils import load_img
import tensorflow as tf 
from matplotlib import pyplot as plt 
import numpy as np
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import tensorflow_hub as hub
#       2 from tensorflow.keras.utils import load_img
#       3 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow_hub'

# %%
import sys
# !{sys.executable} -m pip install tensorflow_hub
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 1.1 MB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.7 MB 1.2 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.7 MB 1.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 1.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.3/1.7 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 1.1 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
#    ---------------------------------------- 0/2 [tf-keras]
# ...

# %%
import tensorflow_hub as hub

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %%
def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_imagae(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

# %%
import sys
# !{sys.executable} -m pip install pillow

# %%
from tensorflow.keras.utils import load_img

content_image = load_img(r'C:\Users\vaish\OneDrive\Pictures\spider_man.jpg')
style_image = load_img(r'C:\Users\vaish\OneDrive\Pictures\sky.jpg')

# %%
import numpy as np

image_array = np.array(content_image)
print(image_array.shape)
# Out:
# (2160, 3840, 3)

# %%
import tensorflow as tf

def load_image(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, (256, 256))  # resize image
    img = img[tf.newaxis, :]  # add batch dimension
    return img

# %%
content_image = load_image(r'C:\Users\vaish\OneDrive\Pictures\spider_man.jpg')
print(content_image.shape)
# Out:
# (1, 256, 256, 3)

# %%
content_image.shape
# Out:
# TensorShape([1, 256, 256, 3])

# %%
import sys
# !{sys.executable} -m pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.utils import load_img

content_image = load_img(r'C:\Users\vaish\OneDrive\Pictures\spider_man.jpg')
plt.imshow(np.array(content_image))
plt.axis('off')
plt.title("Content Image")
plt.show()

# %%
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
import tensorflow as tf

def load_image(img_path, target_size=(256, 256)):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32) 
    img = tf.image.resize(img, target_size)
    img = img[tf.newaxis, :]
    return img

# %%
content_image = load_img(r'C:\Users\vaish\OneDrive\Pictures\spider_man.jpg')
style_image = load_img(r'C:\Users\vaish\OneDrive\Pictures\sky.jpg')

# %%
import sys
# !{sys.executable} -m pip install tensorflow_hub

# %%
# Load content and style images
content_image = load_and_process_image(r'C:\Users\vaish\OneDrive\Pictures\spider_man.jpg')
style_image = load_and_process_image(r'C:\Users\vaish\OneDrive\Pictures\sky.jpg')

# Load a pre-trained style transfer model
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# Generate the stylized image
stylized_image = model(content_image, style_image)[0]

# Display
import matplotlib.pyplot as plt
plt.imshow(tf.squeeze(stylized_image))
plt.axis('off')
plt.title("Stylized Output")
plt.show()
